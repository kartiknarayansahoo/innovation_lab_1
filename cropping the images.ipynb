# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('images/10000016083.tif')

print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv.imshow('window',img)
cv.waitKey(2)
cv.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# ...

# %%
cv.imshow('window',img)
cv.waitKey(2)
cv.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# QObject::moveToThread: Current thread (0x565069452ce0) is not the object's thread (0x565069c12280).
# Cannot move to target thread (0x565069452ce0)
#
# ...
